# %%
# !python main.py --upscale_factor 4 --gpus 2 --hr_train_dataset Guochan_HR \
    --pretrained_sr ./models/DBPN-RES-MR64-3_4x.pth --pretrained True \
        --nEpochs 100 --snapshots 10 --batchSize 32 --prefix Guochan \
            --model_type DBPN-RES-MR64-3 --save_folder weights/DBPN-RES-MR64-3_4x_FT \
                --threads 8
# Out:
# Namespace(upscale_factor=8, batchSize=10, nEpochs=100, snapshots=5, start_iter=1, lr=0.0001, gpu_mode=True, threads=1, seed=123, gpus=2, data_dir='./Dataset', data_augmentation=True, hr_train_dataset='Guochan_HR', model_type='DBPNLL', residual=True, patch_size=40, pretrained_sr='./models/DBPN-RES-MR64-3_4x.pth', pretrained=True, save_folder='weights/', prefix='Guochan')
# ===> Loading datasets
# ===> Building model  DBPNLL
# ---------- Networks architecture -------------
# DataParallel(
#   (module): Net(
#     (feat0): ConvBlock(
#       (conv): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (act): PReLU(num_parameters=1)
#     )
#     (feat1): ConvBlock(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#       (act): PReLU(num_parameters=1)
#     )
#     (up1): UpBlock(
#       (up_conv1): DeconvBlock(
#         (deconv): ConvTranspose2d(64, 64, kernel_size=(12, 12), stride=(8, 8), padding=(2, 2))
# ...
